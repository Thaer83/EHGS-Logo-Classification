# %%
# -*- coding: utf-8 -*-
"""
Customized on Fri May 1 15:50:25 2022

@author: Thaer
"""

# ============ Select optimizers =================
#optimizer=["HGS_UDA","EHGS_UDA"]    # to investigate the basic and enhanced HGS algorithm

optimizer=["BAT_UDA","HHO_UDA", "SCA_UDA"]
#=================================================

# ============ Select tested benchmark function" =================
objectivefunc = []
Functions_No = 30
for i in range (0,Functions_No):
    func = "F"+str(i+1)+"CEC2014"
    objectivefunc.append(func)
#=================================================

# ============ Select number of repetitions for each experiment=================
# To obtain meaningful statistical results, usually 30 independent runs are executed for each algorithm.
NumOfRuns = 30
problem_size = 30
max_nfes = 10000 * problem_size # for CEC2017 functions
PopulationSize = 30
Iterations = 1000  # automatically return the integer part


# Select general parameters for all optimizers (population size, number of iterations) ....
params = {"PopulationSize": PopulationSize, "Iterations": Iterations}  

# Choose whether to Export the results in different formats
export_flags = {
    "Export_avg": True,
    "Export_details": True,
    "Export_diversity": True,
    "Export_convergence": False,
    "Export_boxplot": False,
}

# %%
# Run Framework
from optimizer import run

run(optimizer, objectivefunc, NumOfRuns, params, export_flags)
# Out:
# BAT , F1CEC2014  Run  0 F1CEC2014  completed
# BAT , F1CEC2014  Run  1 F1CEC2014  completed
# BAT , F1CEC2014  Run  2 F1CEC2014  completed
# BAT , F1CEC2014  Run  3 F1CEC2014  completed
# BAT , F1CEC2014  Run  4 F1CEC2014  completed
# BAT , F1CEC2014  Run  5 F1CEC2014  completed
# BAT , F1CEC2014  Run  6 F1CEC2014  completed
# BAT , F1CEC2014  Run  7 F1CEC2014  completed
# BAT , F1CEC2014  Run  8 F1CEC2014  completed
# BAT , F1CEC2014  Run  9 F1CEC2014  completed
# BAT , F1CEC2014  Run  10 F1CEC2014  completed
# BAT , F1CEC2014  Run  11 F1CEC2014  completed
# BAT , F1CEC2014  Run  12 F1CEC2014  completed
# BAT , F1CEC2014  Run  13 F1CEC2014  completed
# BAT , F1CEC2014  Run  14 F1CEC2014  completed
# BAT , F1CEC2014  Run  15 F1CEC2014  completed
# BAT , F1CEC2014  Run  16 F1CEC2014  completed
# BAT , F1CEC2014  Run  17 F1CEC2014  completed
# BAT , F1CEC2014  Run  18 F1CEC2014  completed
# BAT , F1CEC2014  Run  19 F1CEC2014  completed
# BAT , F1CEC2014  Run  20 F1CEC2014  completed
# ...
